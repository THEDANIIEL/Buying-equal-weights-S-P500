# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math

# %%
stocks = pd.read_csv('sp_500_stocks (1).csv')
stocks
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
symbol = 'AAPL'
api_url = f'https://cloud.iexapis.com/stable/stock/{symbol}/quote/?token=pk_a49b9d5141034daa9a79b6c5e8e7dd84'
data = requests.get(api_url).json()
print(data)
# Out:
# {'avgTotalVolume': 72607677, 'calculationPrice': 'close', 'change': -1.14, 'changePercent': -0.0074, 'close': 152.95, 'closeSource': 'official', 'closeTime': 1658779200666, 'companyName': 'Apple Inc', 'currency': 'USD', 'delayedPrice': 152.92, 'delayedPriceTime': 1658779196011, 'extendedChange': -0.35, 'extendedChangePercent': -0.00229, 'extendedPrice': 152.6, 'extendedPriceTime': 1658793599568, 'high': 155.04, 'highSource': '15 minute delayed price', 'highTime': 1658779199995, 'iexAskPrice': 0, 'iexAskSize': 0, 'iexBidPrice': 0, 'iexBidSize': 0, 'iexClose': 152.87, 'iexCloseTime': 1658779198817, 'iexLastUpdated': 1658779198817, 'iexMarketPercent': 0.017177195747161086, 'iexOpen': 154.01, 'iexOpenTime': 1658755800042, 'iexRealtimePrice': 152.87, 'iexRealtimeSize': 400, 'iexVolume': 921109, 'lastTradeTime': 1658779199903, 'latestPrice': 152.95, 'latestSource': 'Close', 'latestTime': 'July 25, 2022', 'latestUpdate': 1658779200666, 'latestVolume': 53623945, 'low': 152.28, 'lowSource': '
# ...

# %%
price = data['latestPrice']
market_cap = data['marketCap']

# %%
my_columns = ['Ticker', 'Stock Price', 'Market Capitalization', 'Number of Shares to Buy']
final_dataframe = pd.DataFrame(columns = my_columns)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Stock Price, Market Capitalization, Number of Shares to Buy]
# Index: []

# %%
final_dataframe.append(
    pd.Series(
    [
        symbol,
        price,
        market_cap,
        'N/A'
        
    ],
    index = my_columns
    ),
    ignore_index = True
    
    
)
# Out:
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/2380860687.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe.append(
#   Ticker Stock Price Market Capitalization Number of Shares to Buy
# 0   AAPL      152.95         2475523433950                     N/A

# %%
final_dataframe = pd.DataFrame(columns = my_columns)
for stock in stocks['Ticker'][:84]:
    api_url = f'https://cloud.iexapis.com/stable/stock/{stock}/quote/?token=pk_a49b9d5141034daa9a79b6c5e8e7dd84'
    data = requests.get(api_url).json()
    final_dataframe = final_dataframe.append(
        pd.Series(
        [
            stock,
            data['latestPrice'],
            data['marketCap'],
            'N/A'
        ],
        index = my_columns),
    ignore_index = True
    )
# Out:
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/2896455480.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/2896455480.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/2896455480.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# ...

# %%
final_dataframe
# Out:
#    Ticker Stock Price Market Capitalization Number of Shares to Buy
# 0       A      124.26           37117463039                     N/A
# 1     AAL       13.75            8935381496                     N/A
# 2     AAP      189.63           11499130015                     N/A
# 3    AAPL      152.95         2475523433950                     N/A
# 4    ABBV      150.22          265455276668                     N/A
# ..    ...         ...                   ...                     ...
# 79    CAT      181.81           96968946201                     N/A
# 80     CB      187.21           79323005390                     N/A
# 81   CBOE      124.75           13247024108                     N/A
# 82   CBRE       82.83           27073859688                     N/A
# 83    CCI       171.5           74264932949                     N/A
#
# [84 rows x 4 columns]

# %%
def chunks(lst, n):
    """yield Successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
 #   print(symbol_strings)
final_dataframe = pd.DataFrame(columns = my_columns)
for symbol_string in symbol_strings:
    batch_api_call_url = f'https://cloud.iexapis.com/stable//stock/market/batch?symbols={symbol_string}&types=quote&token=pk_a49b9d5141034daa9a79b6c5e8e7dd84'
    data =  requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        final_dataframe = final_dataframe.append(
        pd.Series(
        [
           symbol,
           data[symbol]['quote']['latestPrice'],
           data[symbol]['quote']['marketCap'],
           'N/A'
            
        ],
        index = my_columns),
        ignore_index=True
        )
final_dataframe
# Out:
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/4176954614.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/4176954614.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# /var/folders/fq/zgj_k1rx4sl0wk_hjxt78j3w0000gn/T/ipykernel_6405/4176954614.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# ...

# %%
portfolio_size = input("Entre youe portfolio balance:")


try:
    val = float(portfolio_size)
    print(val)    
except ValueError:
    print("The input wa not definde")
    portfolio_size = input("Entre youe portfolio balance:")
    val = float(portfolio_size)
# Out:
# Entre youe portfolio balance:200000
# 200000.0

# %%
position_size = val/len(final_dataframe.index)
for i in range(0, len(final_dataframe.index)):
    final_dataframe.loc[i, "Number of Shares to Buy"] = math.floor(position_size/final_dataframe.loc[i, "Stock Price"])
    
final_dataframe
# Out:
#    Ticker Stock Price Market Capitalization Number of Shares to Buy
# 0       A      124.26           37117463039                      16
# 1     AAL       13.75            8935381496                     145
# 2     AAP      189.63           11499130015                      10
# 3    AAPL      152.95         2475523433950                      13
# 4    ABBV      150.22          265455276668                      13
# ..    ...         ...                   ...                     ...
# 95   CINF      112.55           18047983050                      17
# 96     CL       77.85           65233774579                      25
# 97    CLX      146.59           18042296174                      13
# 98    CMA       78.97           10326141444                      25
# 99  CMCSA       42.47          189865123699                      47
#
# [100 rows x 4 columns]

# %%
writer = pd.ExcelWriter('recommended_trades.xlsx', engine='xlsxwriter')
final_dataframe.to_excel(writer, sheet_name='Recommended Trades', index = False)

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
        {
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

dollar_format = writer.book.add_format(
        {
            'num_format':'$0.00',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

integer_format = writer.book.add_format(
        {
            'num_format':'0',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

# %%
column_formats = { 
                    'A': ['Ticker', string_format],
                    'B': ['Price', dollar_format],
                    'C': ['Market Capitalization', dollar_format],
                    'D': ['Number of Shares to Buy', integer_format]
                    }

for column in column_formats.keys():
    writer.sheets['Recommended Trades'].set_column(f'{column}:{column}', 20, column_formats[column][1])
    writer.sheets['Recommended Trades'].write(f'{column}1', column_formats[column][0], string_format)

# %%
writer.save()
